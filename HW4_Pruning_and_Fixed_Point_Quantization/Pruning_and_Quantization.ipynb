# %% [markdown]
# ### Lab2 (a) Model preperation

# %%
from resnet20 import ResNetCIFAR
from train_util import train, finetune, test
import torch
import numpy as np

import time

import torchvision.transforms as transforms
import torchvision
import torch.nn as nn
import torch.optim as optim

from FP_layers import *

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
net = ResNetCIFAR(num_layers=20, Nbits=None)
net = net.to(device)

# %%
# Load the best weight paramters
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# 100%|██████████| 170M/170M [00:02<00:00, 58.0MB/s]
# Test Loss=0.3231, Test accuracy=0.9151

# %% [markdown]
# The test accuracy for the floating point pretrained model is 0.9151.

# %% [markdown]
# ### Lab2 (b) Prune by percentage

# %%
def prune_by_percentage(layer, q=70.0):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least
    significant weight parameters will be pruned.
    """
    # Convert the weight of "layer" to numpy array
    weight = layer.weight.data.cpu().numpy()

    # Compute the q-th percentile of the abs of the converted array
    threshold = np.percentile(np.abs(weight), q)
    # Generate a binary mask same shape as weight to decide which element to prune
    mask = np.where(np.abs(weight) < threshold, 0, 1)
    # Convert mask to torch tensor and put on GPU
    mask = torch.tensor(mask).to(device)
    # Multiply the weight by mask to perform pruning
    layer.weight.data = layer.weight.data * mask
    pass

# %%
pruning_percentages = [20, 40, 60, 70, 80]

for q in pruning_percentages:
    # Reload the full model checkpoint
    net.load_state_dict(torch.load("pretrained_model.pt"))
    net = net.to(device)

    # Apply pruning by percentage
    for name, layer in net.named_modules():
        if isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear):
            prune_by_percentage(layer, q)
            # Optional: Check the sparsity achieved in each layer
            np_weight = layer.weight.data.cpu().numpy()
            zeros = np.sum(np_weight == 0)
            total = np_weight.size
            print('Sparsity of {} at q={}: {:.2f}%'.format(name, q, (zeros / total) * 100))

    # Test the model
    test_accuracy = test(net)
# Out:
# Sparsity of head_conv.0.conv at q=20: 20.14%
# Sparsity of body_op.0.conv1.0.conv at q=20: 20.01%
# Sparsity of body_op.0.conv2.0.conv at q=20: 20.01%
# Sparsity of body_op.1.conv1.0.conv at q=20: 20.01%
# Sparsity of body_op.1.conv2.0.conv at q=20: 20.01%
# Sparsity of body_op.2.conv1.0.conv at q=20: 20.01%
# Sparsity of body_op.2.conv2.0.conv at q=20: 20.01%
# Sparsity of body_op.3.conv1.0.conv at q=20: 20.01%
# Sparsity of body_op.3.conv2.0.conv at q=20: 20.00%
# Sparsity of body_op.3.id_mapping.0.conv at q=20: 20.12%
# Sparsity of body_op.4.conv1.0.conv at q=20: 20.00%
# Sparsity of body_op.4.conv2.0.conv at q=20: 20.00%
# Sparsity of body_op.5.conv1.0.conv at q=20: 20.00%
# Sparsity of body_op.5.conv2.0.conv at q=20: 20.00%
# Sparsity of body_op.6.conv1.0.conv at q=20: 20.00%
# Sparsity of body_op.6.conv2.0.conv at q=20: 20.00%
# Sparsity of body_op.6.id_mapping.0.conv at q=20: 20.02%
# Sparsity of body_op.7.conv1.0.conv at q=20: 20.00%
# Sparsity of body_op.7.conv2.0.conv at q=20: 20.00%
# Sparsity of body_op.8.conv1.0.conv at q=20: 20.00%
# Sparsity of body_op.8.conv2.0.conv at q=20: 20.00%
# Sparsity of final_fc.linear at q=20: 20.00%
# Test Loss=0.3452, Test accuracy=0.9081
# Sparsity of head_conv.0.conv at q=40: 40.05%
# Sparsity of body_op.0.conv1.0.conv at q=40: 40.02%
# Sparsity of body_op.0.conv2.0.conv at q=40: 40.02%
# Sparsity of body_op.1.conv1.0.conv at q=40: 40.02%
# Sparsity of body_op.1.conv2.0.conv at q=40: 40.02%
# Sparsity of body_op.2.conv1.0.conv at q=40: 40.02%
# Sparsity of body_op.2.conv2.0.conv at q=40: 40.02%
# Sparsity of body_op.3.conv1.0.conv at q=40: 40.00%
# Sparsity of body_op.3.conv2.0.conv at q=40: 40.00%
# Sparsity of body_op.3.id_mapping.0.conv at q=40: 40.04%
# Sparsity of body_op.4.conv1.0.conv at q=40: 40.00%
# Sparsity of body_op.4.conv2.0.conv at q=40: 40.00%
# Sparsity of body_op.5.conv1.0.conv at q=40: 40.00%
# Sparsity of body_op.5.conv2.0.conv at q=40: 40.00%
# Sparsity of body_op.6.conv1.0.conv at q=40: 40.00%
# Sparsity of body_op.6.conv2.0.conv at q=40: 40.00%
# Sparsity of body_op.6.id_mapping.0.conv at q=40: 39.99%
# Sparsity of body_op.7.conv1.0.conv at q=40: 40.00%
# Sparsity of body_op.7.conv2.0.conv at q=40: 40.00%
# Sparsity of body_op.8.conv1.0.conv at q=40: 40.00%
# Sparsity of body_op.8.conv2.0.conv at q=40: 40.00%
# Sparsity of final_fc.linear at q=40: 40.00%
# Test Loss=0.4455, Test accuracy=0.8833
# Sparsity of head_conv.0.conv at q=60: 59.95%
# Sparsity of body_op.0.conv1.0.conv at q=60: 59.98%
# Sparsity of body_op.0.conv2.0.conv at q=60: 59.98%
# Sparsity of body_op.1.conv1.0.conv at q=60: 59.98%
# Sparsity of body_op.1.conv2.0.conv at q=60: 59.98%
# Sparsity of body_op.2.conv1.0.conv at q=60: 59.98%
# Sparsity of body_op.2.conv2.0.conv at q=60: 59.98%
# Sparsity of body_op.3.conv1.0.conv at q=60: 60.00%
# Sparsity of body_op.3.conv2.0.conv at q=60: 59.99%
# Sparsity of body_op.3.id_mapping.0.conv at q=60: 59.96%
# Sparsity of body_op.4.conv1.0.conv at q=60: 59.99%
# Sparsity of body_op.4.conv2.0.conv at q=60: 59.99%
# Sparsity of body_op.5.conv1.0.conv at q=60: 59.99%
# Sparsity of body_op.5.conv2.0.conv at q=60: 59.99%
# Sparsity of body_op.6.conv1.0.conv at q=60: 60.00%
# Sparsity of body_op.6.conv2.0.conv at q=60: 60.00%
# Sparsity of body_op.6.id_mapping.0.conv at q=60: 60.01%
# Sparsity of body_op.7.conv1.0.conv at q=60: 60.00%
# Sparsity of body_op.7.conv2.0.conv at q=60: 60.00%
# Sparsity of body_op.8.conv1.0.conv at q=60: 60.00%
# Sparsity of body_op.8.conv2.0.conv at q=60: 60.00%
# Sparsity of final_fc.linear at q=60: 60.00%
# Test Loss=1.5873, Test accuracy=0.6376
# Sparsity of head_conv.0.conv at q=70: 69.91%
# Sparsity of body_op.0.conv1.0.conv at q=70: 70.01%
# Sparsity of body_op.0.conv2.0.conv at q=70: 70.01%
# Sparsity of body_op.1.conv1.0.conv at q=70: 70.01%
# Sparsity of body_op.1.conv2.0.conv at q=70: 70.01%
# Sparsity of body_op.2.conv1.0.conv at q=70: 70.01%
# Sparsity of body_op.2.conv2.0.conv at q=70: 70.01%
# Sparsity of body_op.3.conv1.0.conv at q=70: 69.99%
# Sparsity of body_op.3.conv2.0.conv at q=70: 70.00%
# Sparsity of body_op.3.id_mapping.0.conv at q=70: 69.92%
# Sparsity of body_op.4.conv1.0.conv at q=70: 70.00%
# Sparsity of body_op.4.conv2.0.conv at q=70: 70.00%
# Sparsity of body_op.5.conv1.0.conv at q=70: 70.00%
# Sparsity of body_op.5.conv2.0.conv at q=70: 70.00%
# Sparsity of body_op.6.conv1.0.conv at q=70: 70.00%
# Sparsity of body_op.6.conv2.0.conv at q=70: 70.00%
# Sparsity of body_op.6.id_mapping.0.conv at q=70: 69.97%
# Sparsity of body_op.7.conv1.0.conv at q=70: 70.00%
# Sparsity of body_op.7.conv2.0.conv at q=70: 70.00%
# Sparsity of body_op.8.conv1.0.conv at q=70: 70.00%
# Sparsity of body_op.8.conv2.0.conv at q=70: 70.00%
# Sparsity of final_fc.linear at q=70: 70.00%
# Test Loss=3.2800, Test accuracy=0.3607
# Sparsity of head_conv.0.conv at q=80: 79.86%
# Sparsity of body_op.0.conv1.0.conv at q=80: 79.99%
# Sparsity of body_op.0.conv2.0.conv at q=80: 79.99%
# Sparsity of body_op.1.conv1.0.conv at q=80: 79.99%
# Sparsity of body_op.1.conv2.0.conv at q=80: 79.99%
# Sparsity of body_op.2.conv1.0.conv at q=80: 79.99%
# Sparsity of body_op.2.conv2.0.conv at q=80: 79.99%
# Sparsity of body_op.3.conv1.0.conv at q=80: 79.99%
# Sparsity of body_op.3.conv2.0.conv at q=80: 79.99%
# Sparsity of body_op.3.id_mapping.0.conv at q=80: 79.88%
# Sparsity of body_op.4.conv1.0.conv at q=80: 79.99%
# Sparsity of body_op.4.conv2.0.conv at q=80: 79.99%
# Sparsity of body_op.5.conv1.0.conv at q=80: 79.99%
# Sparsity of body_op.5.conv2.0.conv at q=80: 79.99%
# Sparsity of body_op.6.conv1.0.conv at q=80: 80.00%
# Sparsity of body_op.6.conv2.0.conv at q=80: 80.00%
# Sparsity of body_op.6.id_mapping.0.conv at q=80: 79.98%
# Sparsity of body_op.7.conv1.0.conv at q=80: 80.00%
# Sparsity of body_op.7.conv2.0.conv at q=80: 80.00%
# Sparsity of body_op.8.conv1.0.conv at q=80: 80.00%
# Sparsity of body_op.8.conv2.0.conv at q=80: 80.00%
# Sparsity of final_fc.linear at q=80: 80.00%
# Test Loss=8.1436, Test accuracy=0.1001

# %% [markdown]
# ### Lab2 (c) Finetune pruned model

# %%
def finetune_after_prune(net, trainloader, criterion, optimizer, prune=True):
    """
    Finetune the pruned model for a single epoch
    Make sure pruned weights are kept as zero
    """
    # Build a dictionary for the nonzero weights
    weight_mask = {}
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Your code here: generate a mask in GPU torch tensor to have 1 for nonzero element and 0 for zero element
            weight_mask[name] = (layer.weight.data !=0).int().to(device)

    global_steps = 0
    train_loss = 0
    correct = 0
    total = 0
    start = time.time()
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        if prune:
            for name,layer in net.named_modules():
                if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                    # Your code here: Use weight_mask to make sure zero elements remains zero
                    layer.weight.data = layer.weight.data * weight_mask[name]

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        global_steps += 1

        if global_steps % 50 == 0:
            end = time.time()
            batch_size = 256
            num_examples_per_second = 50 * batch_size / (end - start)
            print("[Step=%d]\tLoss=%.4f\tacc=%.4f\t%.1f examples/second"
                 % (global_steps, train_loss / (batch_idx + 1), (correct / total), num_examples_per_second))
            start = time.time()

# %%
# Get pruned model
net.load_state_dict(torch.load("pretrained_model.pt"))
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        prune_by_percentage(layer, q=80.0)

# Training setup, do not change
batch_size=256
lr=0.002
reg=1e-4

print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=16)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.875, weight_decay=reg, nesterov=False)
# Out:
# ==> Preparing data..
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# Model finetuning
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    net.train()
    finetune_after_prune(net, trainloader, criterion, optimizer)
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))

    if val_acc > best_acc:
        best_acc = val_acc
        print("Saving...")
        torch.save(net.state_dict(), "net_after_finetune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.9803	acc=0.6842	1527.4 examples/second
# [Step=100]	Loss=0.8045	acc=0.7366	2867.6 examples/second
# [Step=150]	Loss=0.7190	acc=0.7623	2282.1 examples/second
# Test Loss=0.5568, Test acc=0.8169
# Saving...
#
# Epoch: 1
# [Step=50]	Loss=0.4786	acc=0.8396	1598.2 examples/second
# [Step=100]	Loss=0.4596	acc=0.8451	2866.2 examples/second
# [Step=150]	Loss=0.4511	acc=0.8480	2167.1 examples/second
# Test Loss=0.4857, Test acc=0.8393
# Saving...
#
# Epoch: 2
# [Step=50]	Loss=0.3929	acc=0.8648	1588.5 examples/second
# [Step=100]	Loss=0.3916	acc=0.8648	2845.4 examples/second
# [Step=150]	Loss=0.3908	acc=0.8647	2815.1 examples/second
# Test Loss=0.4530, Test acc=0.8508
# Saving...
#
# Epoch: 3
# [Step=50]	Loss=0.3729	acc=0.8695	1692.3 examples/second
# [Step=100]	Loss=0.3663	acc=0.8732	2388.1 examples/second
# [Step=150]	Loss=0.3633	acc=0.8746	2865.0 examples/second
# Test Loss=0.4344, Test acc=0.8563
# Saving...
#
# Epoch: 4
# [Step=50]	Loss=0.3430	acc=0.8823	1838.0 examples/second
# [Step=100]	Loss=0.3464	acc=0.8810	2310.5 examples/second
# [Step=150]	Loss=0.3386	acc=0.8840	2726.2 examples/second
# Test Loss=0.4232, Test acc=0.8591
# Saving...
#
# Epoch: 5
# [Step=50]	Loss=0.3211	acc=0.8879	1824.0 examples/second
# [Step=100]	Loss=0.3209	acc=0.8884	2377.0 examples/second
# [Step=150]	Loss=0.3207	acc=0.8884	2738.4 examples/second
# Test Loss=0.4118, Test acc=0.8639
# Saving...
#
# Epoch: 6
# [Step=50]	Loss=0.3072	acc=0.8946	1678.5 examples/second
# [Step=100]	Loss=0.3080	acc=0.8952	2678.2 examples/second
# [Step=150]	Loss=0.3082	acc=0.8950	2433.4 examples/second
# Test Loss=0.4050, Test acc=0.8658
# Saving...
#
# Epoch: 7
# [Step=50]	Loss=0.3077	acc=0.8950	1518.2 examples/second
# [Step=100]	Loss=0.3023	acc=0.8979	2868.2 examples/second
# [Step=150]	Loss=0.2994	acc=0.8988	2296.4 examples/second
# Test Loss=0.3996, Test acc=0.8676
# Saving...
#
# Epoch: 8
# [Step=50]	Loss=0.2956	acc=0.8974	1578.3 examples/second
# [Step=100]	Loss=0.2955	acc=0.8984	2675.8 examples/second
# [Step=150]	Loss=0.2946	acc=0.8980	2373.5 examples/second
# Test Loss=0.3929, Test acc=0.8690
# Saving...
#
# Epoch: 9
# [Step=50]	Loss=0.2886	acc=0.9002	1578.9 examples/second
# [Step=100]	Loss=0.2915	acc=0.8978	2796.4 examples/second
# [Step=150]	Loss=0.2894	acc=0.8992	2765.6 examples/second
# Test Loss=0.3903, Test acc=0.8701
# Saving...
#
# Epoch: 10
# [Step=50]	Loss=0.2864	acc=0.8998	1712.6 examples/second
# [Step=100]	Loss=0.2825	acc=0.9016	2468.0 examples/second
# [Step=150]	Loss=0.2814	acc=0.9027	2891.0 examples/second
# Test Loss=0.3874, Test acc=0.8712
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.2735	acc=0.9055	1755.3 examples/second
# [Step=100]	Loss=0.2739	acc=0.9056	2315.9 examples/second
# [Step=150]	Loss=0.2753	acc=0.9048	2842.9 examples/second
# Test Loss=0.3836, Test acc=0.8721
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.2636	acc=0.9095	1841.9 examples/second
# [Step=100]	Loss=0.2714	acc=0.9069	2159.7 examples/second
# [Step=150]	Loss=0.2698	acc=0.9073	2861.7 examples/second
# Test Loss=0.3799, Test acc=0.8738
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.2671	acc=0.9077	1721.9 examples/second
# [Step=100]	Loss=0.2679	acc=0.9062	2718.8 examples/second
# [Step=150]	Loss=0.2658	acc=0.9077	2269.9 examples/second
# Test Loss=0.3778, Test acc=0.8764
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.2627	acc=0.9099	1550.4 examples/second
# [Step=100]	Loss=0.2605	acc=0.9091	2805.7 examples/second
# [Step=150]	Loss=0.2588	acc=0.9093	2289.9 examples/second
# Test Loss=0.3742, Test acc=0.8761
#
# Epoch: 15
# [Step=50]	Loss=0.2510	acc=0.9124	1573.9 examples/second
# [Step=100]	Loss=0.2513	acc=0.9126	2833.1 examples/second
# [Step=150]	Loss=0.2531	acc=0.9120	2376.6 examples/second
# Test Loss=0.3726, Test acc=0.8777
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2564	acc=0.9101	1515.4 examples/second
# [Step=100]	Loss=0.2504	acc=0.9123	2812.9 examples/second
# [Step=150]	Loss=0.2512	acc=0.9127	2795.7 examples/second
# Test Loss=0.3708, Test acc=0.8781
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.2466	acc=0.9154	1635.0 examples/second
# [Step=100]	Loss=0.2471	acc=0.9154	2374.1 examples/second
# [Step=150]	Loss=0.2492	acc=0.9142	2871.0 examples/second
# Test Loss=0.3675, Test acc=0.8783
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.2419	acc=0.9170	1821.7 examples/second
# [Step=100]	Loss=0.2458	acc=0.9151	2308.2 examples/second
# [Step=150]	Loss=0.2439	acc=0.9152	2796.9 examples/second
# Test Loss=0.3683, Test acc=0.8787
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.2346	acc=0.9193	1798.1 examples/second
# [Step=100]	Loss=0.2428	acc=0.9149	2318.6 examples/second
# [Step=150]	Loss=0.2429	acc=0.9159	2778.2 examples/second
# Test Loss=0.3670, Test acc=0.8799
# Saving...

# %%
# Check sparsity of the finetuned model, make sure it's not changed
net.load_state_dict(torch.load("net_after_finetune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.data.cpu().numpy()
        # Count number of zeros
        zeros = np.sum(np_weight == 0)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))

test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7986111111111112
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.4.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.4.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.5.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.5.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# Sparsity of final_fc.linear: 0.8
# Test Loss=0.3670, Test accuracy=0.8799

# %% [markdown]
# ### Lab2 (d) Iterative pruning

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)

    net.train()
    if epoch<10:
        for name,layer in net.named_modules():
            if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                # Increase model sparsity
                q = epoch * 8
                prune_by_percentage(layer, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)

    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))

    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0484	acc=0.9841	1816.0 examples/second
# [Step=100]	Loss=0.0485	acc=0.9844	2305.3 examples/second
# [Step=150]	Loss=0.0480	acc=0.9848	2818.3 examples/second
# Test Loss=0.3245, Test acc=0.9148
#
# Epoch: 1
# [Step=50]	Loss=0.0451	acc=0.9869	1707.1 examples/second
# [Step=100]	Loss=0.0467	acc=0.9855	2332.0 examples/second
# [Step=150]	Loss=0.0472	acc=0.9850	2822.2 examples/second
# Test Loss=0.3257, Test acc=0.9148
#
# Epoch: 2
# [Step=50]	Loss=0.0511	acc=0.9830	1827.7 examples/second
# [Step=100]	Loss=0.0501	acc=0.9840	2276.3 examples/second
# [Step=150]	Loss=0.0508	acc=0.9832	2627.3 examples/second
# Test Loss=0.3278, Test acc=0.9135
#
# Epoch: 3
# [Step=50]	Loss=0.0535	acc=0.9829	1621.8 examples/second
# [Step=100]	Loss=0.0525	acc=0.9830	2784.4 examples/second
# [Step=150]	Loss=0.0532	acc=0.9832	2206.8 examples/second
# Test Loss=0.3284, Test acc=0.9129
#
# Epoch: 4
# [Step=50]	Loss=0.0575	acc=0.9809	1587.4 examples/second
# [Step=100]	Loss=0.0561	acc=0.9812	2827.8 examples/second
# [Step=150]	Loss=0.0570	acc=0.9811	2284.0 examples/second
# Test Loss=0.3327, Test acc=0.9111
#
# Epoch: 5
# [Step=50]	Loss=0.0674	acc=0.9794	1564.4 examples/second
# [Step=100]	Loss=0.0676	acc=0.9783	2845.8 examples/second
# [Step=150]	Loss=0.0664	acc=0.9783	2379.0 examples/second
# Test Loss=0.3373, Test acc=0.9102
#
# Epoch: 6
# [Step=50]	Loss=0.0927	acc=0.9675	1499.5 examples/second
# [Step=100]	Loss=0.0884	acc=0.9694	2879.8 examples/second
# [Step=150]	Loss=0.0861	acc=0.9702	2859.3 examples/second
# Test Loss=0.3364, Test acc=0.9051
#
# Epoch: 7
# [Step=50]	Loss=0.1292	acc=0.9563	1795.1 examples/second
# [Step=100]	Loss=0.1264	acc=0.9566	2344.1 examples/second
# [Step=150]	Loss=0.1207	acc=0.9582	2673.2 examples/second
# Test Loss=0.3385, Test acc=0.9010
#
# Epoch: 8
# [Step=50]	Loss=0.1876	acc=0.9343	1805.7 examples/second
# [Step=100]	Loss=0.1742	acc=0.9395	2285.7 examples/second
# [Step=150]	Loss=0.1672	acc=0.9417	2855.8 examples/second
# Test Loss=0.3481, Test acc=0.8923
#
# Epoch: 9
# [Step=50]	Loss=0.3136	acc=0.8922	1810.7 examples/second
# [Step=100]	Loss=0.2930	acc=0.8984	2378.5 examples/second
# [Step=150]	Loss=0.2820	acc=0.9021	2711.1 examples/second
# Test Loss=0.3995, Test acc=0.8745
#
# Epoch: 10
# [Step=50]	Loss=0.2373	acc=0.9176	1595.1 examples/second
# [Step=100]	Loss=0.2352	acc=0.9170	2684.1 examples/second
# [Step=150]	Loss=0.2292	acc=0.9201	2411.2 examples/second
# Test Loss=0.3808, Test acc=0.8801
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.2267	acc=0.9217	1584.0 examples/second
# [Step=100]	Loss=0.2213	acc=0.9224	2605.2 examples/second
# [Step=150]	Loss=0.2158	acc=0.9248	2345.1 examples/second
# Test Loss=0.3722, Test acc=0.8832
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.1962	acc=0.9323	1586.5 examples/second
# [Step=100]	Loss=0.2019	acc=0.9301	2935.8 examples/second
# [Step=150]	Loss=0.2015	acc=0.9306	2411.0 examples/second
# Test Loss=0.3642, Test acc=0.8844
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.1989	acc=0.9321	1595.9 examples/second
# [Step=100]	Loss=0.1974	acc=0.9325	2875.5 examples/second
# [Step=150]	Loss=0.1974	acc=0.9326	2872.6 examples/second
# Test Loss=0.3600, Test acc=0.8857
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.1931	acc=0.9347	1716.6 examples/second
# [Step=100]	Loss=0.1909	acc=0.9343	2381.0 examples/second
# [Step=150]	Loss=0.1868	acc=0.9371	2854.7 examples/second
# Test Loss=0.3553, Test acc=0.8876
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.1835	acc=0.9355	1813.3 examples/second
# [Step=100]	Loss=0.1826	acc=0.9368	2173.8 examples/second
# [Step=150]	Loss=0.1830	acc=0.9364	2816.0 examples/second
# Test Loss=0.3544, Test acc=0.8885
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.1824	acc=0.9365	1803.3 examples/second
# [Step=100]	Loss=0.1814	acc=0.9373	2299.8 examples/second
# [Step=150]	Loss=0.1785	acc=0.9386	2566.4 examples/second
# Test Loss=0.3506, Test acc=0.8896
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.1731	acc=0.9395	1734.3 examples/second
# [Step=100]	Loss=0.1716	acc=0.9404	2599.5 examples/second
# [Step=150]	Loss=0.1738	acc=0.9398	2452.7 examples/second
# Test Loss=0.3494, Test acc=0.8888
#
# Epoch: 18
# [Step=50]	Loss=0.1650	acc=0.9425	1555.6 examples/second
# [Step=100]	Loss=0.1648	acc=0.9427	2876.3 examples/second
# [Step=150]	Loss=0.1676	acc=0.9419	2299.5 examples/second
# Test Loss=0.3452, Test acc=0.8904
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.1637	acc=0.9419	1518.8 examples/second
# [Step=100]	Loss=0.1671	acc=0.9409	2857.6 examples/second
# [Step=150]	Loss=0.1689	acc=0.9406	2525.2 examples/second
# Test Loss=0.3452, Test acc=0.8909
# Saving...

# %%
# Check sparsity of the final model, make sure it's 80%
net.load_state_dict(torch.load("net_after_iterative_prune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here: can copy from previous question
        np_weight = layer.weight.data.cpu().numpy()
        zeros = np.sum(np_weight == 0)
        total = np_weight.size
        print('Sparsity of ' + name + ': ' + str(zeros / total))


test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7199074074074074
# Sparsity of body_op.0.conv1.0.conv: 0.7200520833333334
# Sparsity of body_op.0.conv2.0.conv: 0.7200520833333334
# Sparsity of body_op.1.conv1.0.conv: 0.7200520833333334
# Sparsity of body_op.1.conv2.0.conv: 0.7200520833333334
# Sparsity of body_op.2.conv1.0.conv: 0.7200520833333334
# Sparsity of body_op.2.conv2.0.conv: 0.7200520833333334
# Sparsity of body_op.3.conv1.0.conv: 0.7200520833333334
# Sparsity of body_op.3.conv2.0.conv: 0.7199435763888888
# Sparsity of body_op.4.conv1.0.conv: 0.7199435763888888
# Sparsity of body_op.4.conv2.0.conv: 0.7199435763888888
# Sparsity of body_op.5.conv1.0.conv: 0.7199435763888888
# Sparsity of body_op.5.conv2.0.conv: 0.7199435763888888
# Sparsity of body_op.6.conv1.0.conv: 0.7199978298611112
# Sparsity of body_op.6.conv2.0.conv: 0.7199978298611112
# Sparsity of body_op.7.conv1.0.conv: 0.7199978298611112
# Sparsity of body_op.7.conv2.0.conv: 0.7199978298611112
# Sparsity of body_op.8.conv1.0.conv: 0.7199978298611112
# Sparsity of body_op.8.conv2.0.conv: 0.7199978298611112
# Sparsity of final_fc.linear: 0.7203125
# Test Loss=0.3452, Test accuracy=0.8909

# %% [markdown]
# ### Lab2 (e) Global iterative pruning

# %%
def global_prune_by_percentage(net, q=70.0):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least
    significant weight parameters will be pruned.
    """
    # A list to gather all the weights
    flattened_weights = []
    # Find global pruning threshold
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            weight = layer.weight.data.cpu().numpy()
            # Flatten the weight and append to flattened_weights
            flattened_weights.append(weight.flatten())

    # Concate all weights into a np array
    flattened_weights = np.concatenate(flattened_weights)
    # Find global pruning threshold
    thres = np.percentile(np.abs(flattened_weights), q)

    # Apply pruning threshold to all layers
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            weight = layer.weight.data.cpu().numpy()

            # Generate a binary mask same shape as weight to decide which element to prune
            mask = np.where(np.abs(weight) < thres, 0, 1)

            # Convert mask to torch tensor and put on GPU
            mask = torch.tensor(mask).to(device)

            # Multiply the weight by mask to perform pruning
            layer.weight.data = layer.weight.data * mask

            pass

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)

    net.train()
    if epoch<10:
        # Increase model sparsity
        q = epoch * 8
        global_prune_by_percentage(net, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)

    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))

    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_global_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0473	acc=0.9849	1499.1 examples/second
# [Step=100]	Loss=0.0485	acc=0.9841	2799.9 examples/second
# [Step=150]	Loss=0.0482	acc=0.9843	2297.5 examples/second
# Test Loss=0.3247, Test acc=0.9150
#
# Epoch: 1
# [Step=50]	Loss=0.0470	acc=0.9854	1569.8 examples/second
# [Step=100]	Loss=0.0473	acc=0.9846	2876.5 examples/second
# [Step=150]	Loss=0.0473	acc=0.9846	2309.3 examples/second
# Test Loss=0.3269, Test acc=0.9143
#
# Epoch: 2
# [Step=50]	Loss=0.0456	acc=0.9852	1570.6 examples/second
# [Step=100]	Loss=0.0467	acc=0.9850	2836.0 examples/second
# [Step=150]	Loss=0.0469	acc=0.9851	2885.9 examples/second
# Test Loss=0.3268, Test acc=0.9141
#
# Epoch: 3
# [Step=50]	Loss=0.0507	acc=0.9841	1776.6 examples/second
# [Step=100]	Loss=0.0520	acc=0.9827	2416.5 examples/second
# [Step=150]	Loss=0.0509	acc=0.9835	2855.5 examples/second
# Test Loss=0.3277, Test acc=0.9144
#
# Epoch: 4
# [Step=50]	Loss=0.0566	acc=0.9800	1727.1 examples/second
# [Step=100]	Loss=0.0544	acc=0.9816	2269.1 examples/second
# [Step=150]	Loss=0.0550	acc=0.9819	2827.8 examples/second
# Test Loss=0.3281, Test acc=0.9126
#
# Epoch: 5
# [Step=50]	Loss=0.0653	acc=0.9787	1780.1 examples/second
# [Step=100]	Loss=0.0613	acc=0.9800	2154.3 examples/second
# [Step=150]	Loss=0.0590	acc=0.9810	2822.3 examples/second
# Test Loss=0.3253, Test acc=0.9121
#
# Epoch: 6
# [Step=50]	Loss=0.0713	acc=0.9760	1642.5 examples/second
# [Step=100]	Loss=0.0712	acc=0.9755	2644.5 examples/second
# [Step=150]	Loss=0.0710	acc=0.9757	2441.9 examples/second
# Test Loss=0.3275, Test acc=0.9070
#
# Epoch: 7
# [Step=50]	Loss=0.0926	acc=0.9682	1548.5 examples/second
# [Step=100]	Loss=0.0935	acc=0.9683	2861.8 examples/second
# [Step=150]	Loss=0.0917	acc=0.9690	2297.4 examples/second
# Test Loss=0.3261, Test acc=0.9067
#
# Epoch: 8
# [Step=50]	Loss=0.1353	acc=0.9545	1486.7 examples/second
# [Step=100]	Loss=0.1299	acc=0.9556	2837.8 examples/second
# [Step=150]	Loss=0.1282	acc=0.9558	2309.2 examples/second
# Test Loss=0.3249, Test acc=0.9011
#
# Epoch: 9
# [Step=50]	Loss=0.2114	acc=0.9268	1488.4 examples/second
# [Step=100]	Loss=0.2102	acc=0.9273	2652.1 examples/second
# [Step=150]	Loss=0.2048	acc=0.9292	2543.9 examples/second
# Test Loss=0.3539, Test acc=0.8823
#
# Epoch: 10
# [Step=50]	Loss=0.1854	acc=0.9363	1542.4 examples/second
# [Step=100]	Loss=0.1836	acc=0.9366	2655.2 examples/second
# [Step=150]	Loss=0.1828	acc=0.9375	2643.0 examples/second
# Test Loss=0.3404, Test acc=0.8870
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.1789	acc=0.9402	1700.5 examples/second
# [Step=100]	Loss=0.1765	acc=0.9400	2438.9 examples/second
# [Step=150]	Loss=0.1756	acc=0.9410	2776.6 examples/second
# Test Loss=0.3343, Test acc=0.8885
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.1581	acc=0.9475	1787.0 examples/second
# [Step=100]	Loss=0.1613	acc=0.9453	2266.0 examples/second
# [Step=150]	Loss=0.1615	acc=0.9449	2844.5 examples/second
# Test Loss=0.3302, Test acc=0.8899
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.1649	acc=0.9434	1658.0 examples/second
# [Step=100]	Loss=0.1594	acc=0.9459	2251.8 examples/second
# [Step=150]	Loss=0.1595	acc=0.9456	2714.2 examples/second
# Test Loss=0.3275, Test acc=0.8912
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.1523	acc=0.9470	1757.5 examples/second
# [Step=100]	Loss=0.1528	acc=0.9473	2090.9 examples/second
# [Step=150]	Loss=0.1529	acc=0.9478	2721.2 examples/second
# Test Loss=0.3248, Test acc=0.8918
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.1542	acc=0.9472	1670.3 examples/second
# [Step=100]	Loss=0.1526	acc=0.9485	2382.0 examples/second
# [Step=150]	Loss=0.1506	acc=0.9487	2386.8 examples/second
# Test Loss=0.3221, Test acc=0.8941
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.1520	acc=0.9462	1537.2 examples/second
# [Step=100]	Loss=0.1500	acc=0.9482	2607.3 examples/second
# [Step=150]	Loss=0.1491	acc=0.9487	2352.5 examples/second
# Test Loss=0.3193, Test acc=0.8964
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.1400	acc=0.9532	1521.4 examples/second
# [Step=100]	Loss=0.1410	acc=0.9521	2820.9 examples/second
# [Step=150]	Loss=0.1448	acc=0.9507	2273.3 examples/second
# Test Loss=0.3184, Test acc=0.8959
#
# Epoch: 18
# [Step=50]	Loss=0.1466	acc=0.9532	1465.9 examples/second
# [Step=100]	Loss=0.1467	acc=0.9517	2825.3 examples/second
# [Step=150]	Loss=0.1448	acc=0.9520	2275.9 examples/second
# Test Loss=0.3172, Test acc=0.8960
#
# Epoch: 19
# [Step=50]	Loss=0.1378	acc=0.9518	1563.8 examples/second
# [Step=100]	Loss=0.1394	acc=0.9521	2587.0 examples/second
# [Step=150]	Loss=0.1402	acc=0.9513	2527.4 examples/second
# Test Loss=0.3155, Test acc=0.8972
# Saving...

# %%
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))

zeros_sum = 0
total_sum = 0
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = np.abs(layer.weight.data.cpu().numpy())
        # Count number of zeros
        zeros = np.sum(np_weight == 0)
        # Count number of parameters
        total = np_weight.size
        zeros_sum+=zeros
        total_sum+=total
        print('Sparsity of '+name+': '+str(zeros/total))
print('Total sparsity of: '+str(zeros_sum/total_sum))
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.25462962962962965
# Sparsity of body_op.0.conv1.0.conv: 0.5703125
# Sparsity of body_op.0.conv2.0.conv: 0.5494791666666666
# Sparsity of body_op.1.conv1.0.conv: 0.5347222222222222
# Sparsity of body_op.1.conv2.0.conv: 0.5716145833333334
# Sparsity of body_op.2.conv1.0.conv: 0.5447048611111112
# Sparsity of body_op.2.conv2.0.conv: 0.58203125
# Sparsity of body_op.3.conv1.0.conv: 0.5447048611111112
# Sparsity of body_op.3.conv2.0.conv: 0.6012369791666666
# Sparsity of body_op.4.conv1.0.conv: 0.6385633680555556
# Sparsity of body_op.4.conv2.0.conv: 0.6975911458333334
# Sparsity of body_op.5.conv1.0.conv: 0.6321614583333334
# Sparsity of body_op.5.conv2.0.conv: 0.7259114583333334
# Sparsity of body_op.6.conv1.0.conv: 0.6382378472222222
# Sparsity of body_op.6.conv2.0.conv: 0.6733940972222222
# Sparsity of body_op.7.conv1.0.conv: 0.6844075520833334
# Sparsity of body_op.7.conv2.0.conv: 0.7421332465277778
# Sparsity of body_op.8.conv1.0.conv: 0.7685004340277778
# Sparsity of body_op.8.conv2.0.conv: 0.9467502170138888
# Sparsity of final_fc.linear: 0.1234375
# Total sparsity of: 0.7200002981336832
# Test Loss=0.3155, Test accuracy=0.8972

# %% [markdown]
# ### Lab 3 (b) and (c): Fixed-point quantization

# %%
# Define quantized model and load weight
Nbits = 2 #Change this value to finish (b) and (c)

net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# Test Loss=9.5441, Test accuracy=0.0899

# %%
# Quantized model finetuning
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)
# Out:
# ==> Preparing data..
#
# Epoch: 0
# [Step=50]	Loss=1.3331	acc=0.6201	1654.0 examples/second
# [Step=100]	Loss=1.0715	acc=0.6823	2234.6 examples/second
# [Step=150]	Loss=0.9395	acc=0.7132	2620.7 examples/second
# Test Loss=0.7185, Test acc=0.7820
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.6605	acc=0.7705	1338.2 examples/second
# [Step=250]	Loss=0.5900	acc=0.8010	2554.6 examples/second
# [Step=300]	Loss=0.5633	acc=0.8099	2119.9 examples/second
# [Step=350]	Loss=0.5473	acc=0.8153	2741.2 examples/second
# Test Loss=0.6380, Test acc=0.8034
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.5039	acc=0.8247	1272.0 examples/second
# [Step=450]	Loss=0.4777	acc=0.8371	2669.8 examples/second
# [Step=500]	Loss=0.4632	acc=0.8421	2229.7 examples/second
# [Step=550]	Loss=0.4575	acc=0.8437	2553.9 examples/second
# Test Loss=0.6437, Test acc=0.8000
#
# Epoch: 3
# [Step=600]	Loss=0.4679	acc=0.8382	1267.4 examples/second
# [Step=650]	Loss=0.4293	acc=0.8498	2643.2 examples/second
# [Step=700]	Loss=0.4203	acc=0.8529	2284.7 examples/second
# [Step=750]	Loss=0.4168	acc=0.8552	2700.3 examples/second
# Test Loss=0.5875, Test acc=0.8210
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=0.4293	acc=0.8435	1224.6 examples/second
# [Step=850]	Loss=0.4078	acc=0.8584	2637.2 examples/second
# [Step=900]	Loss=0.4019	acc=0.8591	2249.3 examples/second
# [Step=950]	Loss=0.3947	acc=0.8611	2716.7 examples/second
# Test Loss=0.5363, Test acc=0.8361
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.4113	acc=0.8539	1191.0 examples/second
# [Step=1050]	Loss=0.3889	acc=0.8629	2554.2 examples/second
# [Step=1100]	Loss=0.3831	acc=0.8648	2271.2 examples/second
# [Step=1150]	Loss=0.3786	acc=0.8670	2800.6 examples/second
# Test Loss=0.5082, Test acc=0.8409
# Saving...
#
# Epoch: 6
# [Step=1200]	Loss=0.3580	acc=0.8752	1224.8 examples/second
# [Step=1250]	Loss=0.3617	acc=0.8755	2313.3 examples/second
# [Step=1300]	Loss=0.3605	acc=0.8764	2450.9 examples/second
# [Step=1350]	Loss=0.3589	acc=0.8763	2855.8 examples/second
# Test Loss=0.4970, Test acc=0.8440
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=0.3617	acc=0.8726	1196.8 examples/second
# [Step=1450]	Loss=0.3545	acc=0.8755	2387.3 examples/second
# [Step=1500]	Loss=0.3569	acc=0.8732	2285.3 examples/second
# [Step=1550]	Loss=0.3537	acc=0.8741	2939.7 examples/second
# Test Loss=0.5667, Test acc=0.8302
#
# Epoch: 8
# [Step=1600]	Loss=0.3524	acc=0.8763	1197.9 examples/second
# [Step=1650]	Loss=0.3427	acc=0.8784	2358.6 examples/second
# [Step=1700]	Loss=0.3387	acc=0.8809	2494.6 examples/second
# [Step=1750]	Loss=0.3338	acc=0.8830	2819.2 examples/second
# Test Loss=0.4824, Test acc=0.8476
# Saving...
#
# Epoch: 9
# [Step=1800]	Loss=0.3369	acc=0.8814	1158.7 examples/second
# [Step=1850]	Loss=0.3338	acc=0.8817	2279.3 examples/second
# [Step=1900]	Loss=0.3331	acc=0.8820	2592.4 examples/second
# [Step=1950]	Loss=0.3294	acc=0.8829	3130.4 examples/second
# Test Loss=0.5535, Test acc=0.8316
#
# Epoch: 10
# [Step=2000]	Loss=0.3199	acc=0.8857	1149.4 examples/second
# [Step=2050]	Loss=0.3221	acc=0.8865	2283.6 examples/second
# [Step=2100]	Loss=0.3192	acc=0.8872	2673.1 examples/second
# [Step=2150]	Loss=0.3204	acc=0.8875	3193.2 examples/second
# Test Loss=0.4696, Test acc=0.8518
# Saving...
#
# Epoch: 11
# [Step=2200]	Loss=0.3291	acc=0.8858	1119.6 examples/second
# [Step=2250]	Loss=0.3204	acc=0.8875	2261.6 examples/second
# [Step=2300]	Loss=0.3169	acc=0.8892	2653.3 examples/second
# [Step=2350]	Loss=0.3139	acc=0.8897	3211.2 examples/second
# Test Loss=0.4745, Test acc=0.8534
# Saving...
#
# Epoch: 12
# [Step=2400]	Loss=0.3121	acc=0.8904	1135.7 examples/second
# [Step=2450]	Loss=0.3077	acc=0.8926	2066.0 examples/second
# [Step=2500]	Loss=0.3105	acc=0.8926	2655.0 examples/second
# Test Loss=0.5030, Test acc=0.8444
#
# Epoch: 13
# [Step=2550]	Loss=0.3511	acc=0.8672	1359.6 examples/second
# [Step=2600]	Loss=0.3005	acc=0.8950	2221.3 examples/second
# [Step=2650]	Loss=0.3027	acc=0.8934	2188.7 examples/second
# [Step=2700]	Loss=0.3025	acc=0.8929	2511.9 examples/second
# Test Loss=0.4635, Test acc=0.8547
# Saving...
#
# Epoch: 14
# [Step=2750]	Loss=0.3162	acc=0.8952	995.6 examples/second
# [Step=2800]	Loss=0.3008	acc=0.8960	1816.5 examples/second
# [Step=2850]	Loss=0.2987	acc=0.8974	2626.3 examples/second
# [Step=2900]	Loss=0.3000	acc=0.8951	2525.0 examples/second
# Test Loss=0.4876, Test acc=0.8556
# Saving...
#
# Epoch: 15
# [Step=2950]	Loss=0.2863	acc=0.9020	1251.8 examples/second
# [Step=3000]	Loss=0.2966	acc=0.8934	2192.0 examples/second
# [Step=3050]	Loss=0.2960	acc=0.8950	2684.6 examples/second
# [Step=3100]	Loss=0.2936	acc=0.8950	2666.2 examples/second
# Test Loss=0.4542, Test acc=0.8619
# Saving...
#
# Epoch: 16
# [Step=3150]	Loss=0.2992	acc=0.8915	1279.9 examples/second
# [Step=3200]	Loss=0.2920	acc=0.8971	2325.2 examples/second
# [Step=3250]	Loss=0.2928	acc=0.8965	2511.8 examples/second
# [Step=3300]	Loss=0.2917	acc=0.8970	2649.3 examples/second
# Test Loss=0.6796, Test acc=0.8047
#
# Epoch: 17
# [Step=3350]	Loss=0.2883	acc=0.8969	1239.5 examples/second
# [Step=3400]	Loss=0.2852	acc=0.8988	2320.9 examples/second
# [Step=3450]	Loss=0.2807	acc=0.9009	2605.6 examples/second
# [Step=3500]	Loss=0.2829	acc=0.8995	2812.2 examples/second
# Test Loss=0.4707, Test acc=0.8539
#
# Epoch: 18
# [Step=3550]	Loss=0.2762	acc=0.9054	1193.9 examples/second
# [Step=3600]	Loss=0.2769	acc=0.9035	2149.7 examples/second
# [Step=3650]	Loss=0.2837	acc=0.9020	2576.4 examples/second
# [Step=3700]	Loss=0.2852	acc=0.9011	2786.8 examples/second
# Test Loss=0.4774, Test acc=0.8511
#
# Epoch: 19
# [Step=3750]	Loss=0.2771	acc=0.8993	1246.5 examples/second
# [Step=3800]	Loss=0.2818	acc=0.9003	2181.9 examples/second
# [Step=3850]	Loss=0.2790	acc=0.9010	2525.1 examples/second
# [Step=3900]	Loss=0.2792	acc=0.9007	2883.1 examples/second
# Test Loss=0.5246, Test acc=0.8447
# Test Loss=0.4542, Test accuracy=0.8619

# %% [markdown]
# ### Lab3 (d) Quantize pruned model

# %%
# Define quantized model and load weight
Nbits = 5 #Change this value to finish (d)

net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))
test(net)
# Out:
# Test Loss=0.3212, Test accuracy=0.8952

# %%
# Quantized model finetuning
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)
# Out:
# ==> Preparing data..
#
# Epoch: 0
# [Step=50]	Loss=0.1846	acc=0.9331	1598.1 examples/second
# [Step=100]	Loss=0.1785	acc=0.9355	2177.2 examples/second
# [Step=150]	Loss=0.1723	acc=0.9383	2534.3 examples/second
# Test Loss=0.3404, Test acc=0.8939
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.1450	acc=0.9561	1269.9 examples/second
# [Step=250]	Loss=0.1448	acc=0.9463	2461.2 examples/second
# [Step=300]	Loss=0.1438	acc=0.9474	2184.0 examples/second
# [Step=350]	Loss=0.1424	acc=0.9492	2556.6 examples/second
# Test Loss=0.3339, Test acc=0.8976
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.1474	acc=0.9487	1271.3 examples/second
# [Step=450]	Loss=0.1396	acc=0.9506	2503.2 examples/second
# [Step=500]	Loss=0.1389	acc=0.9513	2213.1 examples/second
# [Step=550]	Loss=0.1420	acc=0.9498	2738.2 examples/second
# Test Loss=0.3214, Test acc=0.8982
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.1333	acc=0.9535	1231.2 examples/second
# [Step=650]	Loss=0.1309	acc=0.9538	2634.1 examples/second
# [Step=700]	Loss=0.1324	acc=0.9537	2248.6 examples/second
# [Step=750]	Loss=0.1325	acc=0.9541	2645.3 examples/second
# Test Loss=0.3191, Test acc=0.9008
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=0.1287	acc=0.9561	1212.3 examples/second
# [Step=850]	Loss=0.1255	acc=0.9563	2659.2 examples/second
# [Step=900]	Loss=0.1272	acc=0.9565	2203.3 examples/second
# [Step=950]	Loss=0.1287	acc=0.9561	2686.9 examples/second
# Test Loss=0.3173, Test acc=0.9012
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.1293	acc=0.9523	1231.0 examples/second
# [Step=1050]	Loss=0.1249	acc=0.9549	2532.3 examples/second
# [Step=1100]	Loss=0.1243	acc=0.9552	2247.4 examples/second
# [Step=1150]	Loss=0.1258	acc=0.9549	2765.0 examples/second
# Test Loss=0.3168, Test acc=0.9048
# Saving...
#
# Epoch: 6
# [Step=1200]	Loss=0.1155	acc=0.9600	1212.3 examples/second
# [Step=1250]	Loss=0.1177	acc=0.9605	2731.1 examples/second
# [Step=1300]	Loss=0.1202	acc=0.9595	2096.8 examples/second
# [Step=1350]	Loss=0.1200	acc=0.9594	2862.8 examples/second
# Test Loss=0.3105, Test acc=0.9022
#
# Epoch: 7
# [Step=1400]	Loss=0.1113	acc=0.9626	1185.4 examples/second
# [Step=1450]	Loss=0.1167	acc=0.9613	2534.8 examples/second
# [Step=1500]	Loss=0.1194	acc=0.9598	2069.9 examples/second
# [Step=1550]	Loss=0.1197	acc=0.9596	2709.5 examples/second
# Test Loss=0.3102, Test acc=0.9042
#
# Epoch: 8
# [Step=1600]	Loss=0.1138	acc=0.9606	1110.5 examples/second
# [Step=1650]	Loss=0.1127	acc=0.9610	2223.8 examples/second
# [Step=1700]	Loss=0.1146	acc=0.9605	2339.8 examples/second
# [Step=1750]	Loss=0.1166	acc=0.9598	2743.1 examples/second
# Test Loss=0.3168, Test acc=0.9027
#
# Epoch: 9
# [Step=1800]	Loss=0.1163	acc=0.9582	1078.3 examples/second
# [Step=1850]	Loss=0.1148	acc=0.9598	2078.3 examples/second
# [Step=1900]	Loss=0.1151	acc=0.9600	2578.1 examples/second
# [Step=1950]	Loss=0.1154	acc=0.9596	3068.3 examples/second
# Test Loss=0.3215, Test acc=0.9038
#
# Epoch: 10
# [Step=2000]	Loss=0.1021	acc=0.9673	1143.1 examples/second
# [Step=2050]	Loss=0.1052	acc=0.9645	2182.1 examples/second
# [Step=2100]	Loss=0.1096	acc=0.9626	2615.1 examples/second
# [Step=2150]	Loss=0.1100	acc=0.9620	3171.2 examples/second
# Test Loss=0.3177, Test acc=0.9026
#
# Epoch: 11
# [Step=2200]	Loss=0.1117	acc=0.9630	1070.2 examples/second
# [Step=2250]	Loss=0.1091	acc=0.9628	2184.9 examples/second
# [Step=2300]	Loss=0.1085	acc=0.9626	2578.7 examples/second
# [Step=2350]	Loss=0.1078	acc=0.9624	3204.7 examples/second
# Test Loss=0.3188, Test acc=0.9023
#
# Epoch: 12
# [Step=2400]	Loss=0.1054	acc=0.9624	1140.4 examples/second
# [Step=2450]	Loss=0.1058	acc=0.9622	2073.2 examples/second
# [Step=2500]	Loss=0.1051	acc=0.9628	2664.8 examples/second
# Test Loss=0.3258, Test acc=0.9038
#
# Epoch: 13
# [Step=2550]	Loss=0.1098	acc=0.9570	1373.3 examples/second
# [Step=2600]	Loss=0.1056	acc=0.9622	2242.9 examples/second
# [Step=2650]	Loss=0.1064	acc=0.9619	2102.6 examples/second
# [Step=2700]	Loss=0.1040	acc=0.9632	2669.9 examples/second
# Test Loss=0.3146, Test acc=0.9072
# Saving...
#
# Epoch: 14
# [Step=2750]	Loss=0.1002	acc=0.9642	1303.0 examples/second
# [Step=2800]	Loss=0.0967	acc=0.9665	2431.0 examples/second
# [Step=2850]	Loss=0.0975	acc=0.9661	2311.1 examples/second
# [Step=2900]	Loss=0.1003	acc=0.9650	2534.3 examples/second
# Test Loss=0.3218, Test acc=0.9065
#
# Epoch: 15
# [Step=2950]	Loss=0.0968	acc=0.9664	1256.6 examples/second
# [Step=3000]	Loss=0.0948	acc=0.9678	2403.7 examples/second
# [Step=3050]	Loss=0.0948	acc=0.9680	2394.4 examples/second
# [Step=3100]	Loss=0.0968	acc=0.9672	2729.4 examples/second
# Test Loss=0.3176, Test acc=0.9082
# Saving...
#
# Epoch: 16
# [Step=3150]	Loss=0.0999	acc=0.9660	1177.7 examples/second
# [Step=3200]	Loss=0.0991	acc=0.9662	2165.1 examples/second
# [Step=3250]	Loss=0.0994	acc=0.9656	2521.9 examples/second
# [Step=3300]	Loss=0.0988	acc=0.9655	2591.8 examples/second
# Test Loss=0.3219, Test acc=0.9066
#
# Epoch: 17
# [Step=3350]	Loss=0.0965	acc=0.9653	1239.8 examples/second
# [Step=3400]	Loss=0.0945	acc=0.9671	2121.4 examples/second
# [Step=3450]	Loss=0.0934	acc=0.9683	2616.0 examples/second
# [Step=3500]	Loss=0.0943	acc=0.9677	2683.6 examples/second
# Test Loss=0.3253, Test acc=0.9068
#
# Epoch: 18
# [Step=3550]	Loss=0.0838	acc=0.9730	1285.1 examples/second
# [Step=3600]	Loss=0.0900	acc=0.9691	2056.4 examples/second
# [Step=3650]	Loss=0.0899	acc=0.9685	2597.2 examples/second
# [Step=3700]	Loss=0.0911	acc=0.9684	2798.4 examples/second
# Test Loss=0.3257, Test acc=0.9077
#
# Epoch: 19
# [Step=3750]	Loss=0.0907	acc=0.9681	1240.3 examples/second
# [Step=3800]	Loss=0.0891	acc=0.9691	2141.8 examples/second
# [Step=3850]	Loss=0.0886	acc=0.9695	2402.9 examples/second
# [Step=3900]	Loss=0.0908	acc=0.9689	2836.2 examples/second
# Test Loss=0.3275, Test acc=0.9083
# Saving...
# Test Loss=0.3275, Test accuracy=0.9083

# %% [markdown]
# ### Lab4 (a) Symmetric quantization
# #### Implement symmetric quantization in FP_layers.py, and repeat the process in (b)

# %%
# check the performance of symmetric quantization with 6, 5, 4, 3, 2 bits
Nbits = 6 #Change this value to finish (b) and (c)

net = ResNetCIFAR(num_layers=20, Nbits=Nbits, symmetric=True)
net = net.to(device)
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# Test Loss=0.3231, Test accuracy=0.9146
